# %%
#환경설정
# !pip -q install torch opencv-python-headless scipy

# %%
# 깃클론(파일 가져오는 용)
# %cd /content
# !git clone -b main https://github.com/KMU-FOCUS/focus-avatar.git
# %cd /content/focus-avatar/project/
# Out:
# /content
# Cloning into 'focus-avatar'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 260 (delta 3), reused 8 (delta 3), pack-reused 242 (from 1)
# Receiving objects: 100% (260/260), 135.47 MiB | 31.86 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# Updating files: 100% (158/158), done.
# /content/focus-avatar

# %%
#(메타데이터경로,영상경로,출력영상경로,소스아바타폴더경로)
# !python -m reenactment.reenact_cli \
  --metadata /content/meta.json \
  --video /content/metadata.mp4 \
  --output-video /content/output_reenact.mp4 \
  --avatar-bank-dir /content/focus-avatar/project/avatar_bank
# Out:
# /content/focus-avatar/project
# {
#   "frames_sampled": 113,
#   "frames_composited": 389,
#   "keyframes_computed": 358,
#   "gpen_load_error": null,
#   "audio_remuxed": false,
#   "audio_remux_error": "source video has no audio stream",
#   "pts_source": "ffprobe",
#   "output_video": "/content/output_reenact.mp4"
# }
